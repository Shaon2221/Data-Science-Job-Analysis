# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df=pd.read_csv("glassdoor_ds_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                   Job Title  \
# 0           0            Software Engineer - Data Science
# 1           1       Quality Systems Data Science Engineer
# 2           2  Inside Sales Representative (Headquarters)
# 3           3                              Data Scientist
# 4           4       Data Science Engineer Full Stack - AI
#
#                Salary Estimate  \
# 0  $60K-$127K (Glassdoor est.)
# 1  $60K-$127K (Glassdoor est.)
# 2  $60K-$127K (Glassdoor est.)
# 3  $60K-$127K (Glassdoor est.)
# 4  $60K-$127K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Join ClearEdge and be a part of the team of me...     4.1
# 1  It is our people behind life’s passions who wi...     3.7
# 2  Becoming a Sales Professional at Red Ventures ...     2.5
# 3  Braxton Technologies is looking for a data sci...     1.6
# 4  Data Science Engineer Full Stack - AI\n\nOverv...     2.8
#
#                               Company Name                Location  \
# 0                           ClearEdge\n4.1  Annapolis Junction, MD
# 1                      Mercury Marine\n3.7         Fond du Lac, WI
# 2                Red Ventures - Sales\n2.5           Charlotte, NC
# 3  Braxton Science & Technology Group\n1.6    Colorado Springs, CO
# 4                            BryterCX\n2.8           United States
#
#                      Size  Founded  Type of ownership  \
# 0     51 to 200 Employees     2002  Company - Private
# 1  1001 to 5000 Employees     1939   Company - Public
# 2  1001 to 5000 Employees     2000  Company - Private
# 3     51 to 200 Employees       -1  Company - Private
# 4     51 to 200 Employees     2000  Company - Private
#
#                                   Industry                  Sector  \
# 0             Computer Hardware & Software  Information Technology
# 1          Consumer Products Manufacturing           Manufacturing
# 2                  Advertising & Marketing       Business Services
# 3                                       -1                      -1
# 4  Enterprise Software & Network Solutions  Information Technology
#
#                       Revenue
# 0     $5 to $10 million (USD)
# 1      $2 to $5 billion (USD)
# 2      $1 to $2 billion (USD)
# 3  Less than $1 million (USD)
# 4    $25 to $50 million (USD)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1034 non-null   int64
#  1   Job Title          1034 non-null   object
#  2   Salary Estimate    1034 non-null   object
#  3   Job Description    1034 non-null   object
#  4   Rating             1034 non-null   float64
#  5   Company Name       1034 non-null   object
#  6   Location           1034 non-null   object
#  7   Size               1034 non-null   object
#  8   Founded            1034 non-null   int64
#  9   Type of ownership  1034 non-null   object
#  10  Industry           1034 non-null   object
#  11  Sector             1034 non-null   object
#  12  Revenue            1034 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 105.1+ KB

# %% [markdown]
# ### Salary Data cleaning

# %%
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)

# %%
df.head()
# Out:
#    Unnamed: 0                                   Job Title  \
# 0           0            Software Engineer - Data Science
# 1           1       Quality Systems Data Science Engineer
# 2           2  Inside Sales Representative (Headquarters)
# 3           3                              Data Scientist
# 4           4       Data Science Engineer Full Stack - AI
#
#                Salary Estimate  \
# 0  $60K-$127K (Glassdoor est.)
# 1  $60K-$127K (Glassdoor est.)
# 2  $60K-$127K (Glassdoor est.)
# 3  $60K-$127K (Glassdoor est.)
# 4  $60K-$127K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Join ClearEdge and be a part of the team of me...     4.1
# 1  It is our people behind life’s passions who wi...     3.7
# 2  Becoming a Sales Professional at Red Ventures ...     2.5
# 3  Braxton Technologies is looking for a data sci...     1.6
# 4  Data Science Engineer Full Stack - AI\n\nOverv...     2.8
#
#                               Company Name                Location  \
# 0                           ClearEdge\n4.1  Annapolis Junction, MD
# 1                      Mercury Marine\n3.7         Fond du Lac, WI
# 2                Red Ventures - Sales\n2.5           Charlotte, NC
# 3  Braxton Science & Technology Group\n1.6    Colorado Springs, CO
# 4                            BryterCX\n2.8           United States
#
#                      Size  Founded  Type of ownership  \
# 0     51 to 200 Employees     2002  Company - Private
# 1  1001 to 5000 Employees     1939   Company - Public
# 2  1001 to 5000 Employees     2000  Company - Private
# 3     51 to 200 Employees       -1  Company - Private
# 4     51 to 200 Employees     2000  Company - Private
#
#                                   Industry                  Sector  \
# 0             Computer Hardware & Software  Information Technology
# 1          Consumer Products Manufacturing           Manufacturing
# 2                  Advertising & Marketing       Business Services
# 3                                       -1                      -1
# 4  Enterprise Software & Network Solutions  Information Technology
#
#                       Revenue  hourly  employer_provided
# 0     $5 to $10 million (USD)       0                  0
# 1      $2 to $5 billion (USD)       0                  0
# 2      $1 to $2 billion (USD)       0                  0
# 3  Less than $1 million (USD)       0                  0
# 4    $25 to $50 million (USD)       0                  0

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
minus_Kd = salary.apply(lambda x: x.replace('K','').replace('$',''))

# %%
min_hr = minus_Kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))

# %%
min_hr.head()
# Out:
# 0    60-127
# 1    60-127
# 2    60-127
# 3    60-127
# 4    60-127
# Name: Salary Estimate, dtype: object

# %%
df['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df.min_salary+df.max_salary)/2

# %% [markdown]
# ### Company name text only

# %%
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-3], axis = 1)

# %% [markdown]
# ### Company Age

# %%
df['age'] = df.Founded.apply(lambda x: x if x <1 else 2020 - x)

# %%
df[df['age']>150]
# Out:
#       Unnamed: 0                                          Job Title  \
# 103          103                                      Data Engineer
# 509          509           Data Scientist - Intermediate (Contract)
# 549          549                                     Data Scientist
# 636          636                                      Data Engineer
# 686          686  Statistician (Data Scientist) *12 month Roster...
# 690          690                                     Data Scientist
# 734          734  Instructor, Business Analytics/Data Science, E...
# 742          742                Sr. Director, Actuarial & Analytics
# 766          766                Sr. Director, Actuarial & Analytics
# 791          791                Sr. Director, Actuarial & Analytics
# 816          816                Sr. Director, Actuarial & Analytics
# 841          841                Sr. Director, Actuarial & Analytics
# 866          866                Sr. Director, Actuarial & Analytics
# 891          891                Sr. Director, Actuarial & Analytics
# 916          916                Sr. Director, Actuarial & Analytics
# 941          941                Sr. Director, Actuarial & Analytics
# 966          966                Sr. Director, Actuarial & Analytics
# 991          991                Sr. Director, Actuarial & Analytics
# 1016        1016                Sr. Director, Actuarial & Analytics
#
#                    Salary Estimate  \
# 103    $83K-$141K (Glassdoor est.)
# 509    $77K-$124K (Glassdoor est.)
# 549    $99K-$165K (Glassdoor est.)
# 636   $115K-$184K (Glassdoor est.)
# 686    $85K-$137K (Glassdoor est.)
# 690    $86K-$138K (Glassdoor est.)
# 734    $66K-$109K (Glassdoor est.)
# 742   $229K-$350K (Glassdoor est.)
# 766   $229K-$350K (Glassdoor est.)
# 791   $229K-$350K (Glassdoor est.)
# 816   $229K-$350K (Glassdoor est.)
# 841   $229K-$350K (Glassdoor est.)
# 866   $229K-$350K (Glassdoor est.)
# 891   $229K-$350K (Glassdoor est.)
# 916   $229K-$350K (Glassdoor est.)
# 941   $229K-$350K (Glassdoor est.)
# 966   $229K-$350K (Glassdoor est.)
# 991   $229K-$350K (Glassdoor est.)
# 1016  $229K-$350K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 103   Why We Work at Dun & Bradstreet\n\n\nWe are at...     3.0
# 509   Data Scientist\n\n\nBasic Qualifications:\nMas...     4.1
# 549   Data Scientist\n\n02-Jul-2020\n\nJob Descripti...     3.3
# 636   As a member of our Software Engineering Group,...     3.9
# 686   The U.S. Department of the Treasury has a dist...     3.6
# 690   Bioinformatics Programmer II\n\n02-Sep-2020\n\...     4.1
# 734   Posting Details\n\nJob Title Instructor, Busin...     4.3
# 742   Company Summary\n\nTaking care of our customer...     4.1
# 766   Company Summary\n\nTaking care of our customer...     4.1
# 791   Company Summary\n\nTaking care of our customer...     4.1
# 816   Company Summary\n\nTaking care of our customer...     4.1
# 841   Company Summary\n\nTaking care of our customer...     4.1
# 866   Company Summary\n\nTaking care of our customer...     4.1
# 891   Company Summary\n\nTaking care of our customer...     4.1
# 916   Company Summary\n\nTaking care of our customer...     4.1
# 941   Company Summary\n\nTaking care of our customer...     4.1
# 966   Company Summary\n\nTaking care of our customer...     4.1
# 991   Company Summary\n\nTaking care of our customer...     4.1
# 1016  Company Summary\n\nTaking care of our customer...     4.1
#
#                            Company Name           Location  \
# 103               Dun & Bradstreet\n3.0        Waltham, MA
# 509                          Bayer\n4.1    Saint Louis, MO
# 549                          Aetna\n3.3      Wellesley, MA
# 636      JPMorgan Chase Bank, N.A.\n3.9        Houston, TX
# 686       Internal Revenue Service\n3.6    Bloomington, MN
# 690               UC San Francisco\n4.1  San Francisco, CA
# 734   University of Nebraska Omaha\n4.3          Omaha, NE
# 742                      Travelers\n4.1       Hartford, CT
# 766                      Travelers\n4.1       Hartford, CT
# 791                      Travelers\n4.1       Hartford, CT
# 816                      Travelers\n4.1       Hartford, CT
# 841                      Travelers\n4.1       Hartford, CT
# 866                      Travelers\n4.1       Hartford, CT
# 891                      Travelers\n4.1       Hartford, CT
# 916                      Travelers\n4.1       Hartford, CT
# 941                      Travelers\n4.1       Hartford, CT
# 966                      Travelers\n4.1       Hartford, CT
# 991                      Travelers\n4.1       Hartford, CT
# 1016                     Travelers\n4.1       Hartford, CT
#
#                          Size  Founded     Type of ownership  \
# 103    1001 to 5000 Employees     1841      Company - Public
# 509   5001 to 10000 Employees     1863     Company - Private
# 549          10000+ Employees     1853      Company - Public
# 636          10000+ Employees     1799      Company - Public
# 686          10000+ Employees     1862            Government
# 690          10000+ Employees     1864  College / University
# 734          10000+ Employees     1869  College / University
# 742          10000+ Employees     1853      Company - Public
# 766          10000+ Employees     1853      Company - Public
# 791          10000+ Employees     1853      Company - Public
# 816          10000+ Employees     1853      Company - Public
# 841          10000+ Employees     1853      Company - Public
# 866          10000+ Employees     1853      Company - Public
# 891          10000+ Employees     1853      Company - Public
# 916          10000+ Employees     1853      Company - Public
# 941          10000+ Employees     1853      Company - Public
# 966          10000+ Employees     1853      Company - Public
# 991          10000+ Employees     1853      Company - Public
# 1016         10000+ Employees     1853      Company - Public
#
#                                    Industry                     Sector  \
# 103                             IT Services     Information Technology
# 509               Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 549                      Insurance Carriers                  Insurance
# 636   Investment Banking & Asset Management                    Finance
# 686                        Federal Agencies                 Government
# 690                                      -1                         -1
# 734                 Colleges & Universities                  Education
# 742                      Insurance Carriers                  Insurance
# 766                      Insurance Carriers                  Insurance
# 791                      Insurance Carriers                  Insurance
# 816                      Insurance Carriers                  Insurance
# 841                      Insurance Carriers                  Insurance
# 866                      Insurance Carriers                  Insurance
# 891                      Insurance Carriers                  Insurance
# 916                      Insurance Carriers                  Insurance
# 941                      Insurance Carriers                  Insurance
# 966                      Insurance Carriers                  Insurance
# 991                      Insurance Carriers                  Insurance
# 1016                     Insurance Carriers                  Insurance
#
#                          Revenue  hourly  employer_provided  min_salary  \
# 103       $1 to $2 billion (USD)       0                  0          83
# 509           $10+ billion (USD)       0                  0          77
# 549           $10+ billion (USD)       0                  0          99
# 636           $10+ billion (USD)       0                  0         115
# 686   Less than $1 million (USD)       0                  0          85
# 690     $25 to $50 million (USD)       0                  0          86
# 734   Less than $1 million (USD)       0                  0          66
# 742           $10+ billion (USD)       0                  0         229
# 766           $10+ billion (USD)       0                  0         229
# 791           $10+ billion (USD)       0                  0         229
# 816           $10+ billion (USD)       0                  0         229
# 841           $10+ billion (USD)       0                  0         229
# 866           $10+ billion (USD)       0                  0         229
# 891           $10+ billion (USD)       0                  0         229
# 916           $10+ billion (USD)       0                  0         229
# 941           $10+ billion (USD)       0                  0         229
# 966           $10+ billion (USD)       0                  0         229
# 991           $10+ billion (USD)       0                  0         229
# 1016          $10+ billion (USD)       0                  0         229
#
#       max_salary  avg_salary                     company_txt  age
# 103          141       112.0              Dun & Bradstreet\n  179
# 509          124       100.5                         Bayer\n  157
# 549          165       132.0                         Aetna\n  167
# 636          184       149.5     JPMorgan Chase Bank, N.A.\n  221
# 686          137       111.0      Internal Revenue Service\n  158
# 690          138       112.0              UC San Francisco\n  156
# 734          109        87.5  University of Nebraska Omaha\n  151
# 742          350       289.5                     Travelers\n  167
# 766          350       289.5                     Travelers\n  167
# 791          350       289.5                     Travelers\n  167
# 816          350       289.5                     Travelers\n  167
# 841          350       289.5                     Travelers\n  167
# 866          350       289.5                     Travelers\n  167
# 891          350       289.5                     Travelers\n  167
# 916          350       289.5                     Travelers\n  167
# 941          350       289.5                     Travelers\n  167
# 966          350       289.5                     Travelers\n  167
# 991          350       289.5                     Travelers\n  167
# 1016         350       289.5                     Travelers\n  167

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (760, 19)

# %% [markdown]
# ### Data Science Tools

# %%
#python
df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df.python_yn.value_counts()
# Out:
# 1    491
# 0    269
# Name: python_yn, dtype: int64

# %%
#r studio 
df['R_yn'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
df.R_yn.value_counts()
# Out:
# 0    753
# 1      7
# Name: R_yn, dtype: int64

# %%
#spark 
df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df.spark.value_counts()
# Out:
# 0    589
# 1    171
# Name: spark, dtype: int64

# %%
#aws 
df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df.aws.value_counts()
# Out:
# 0    545
# 1    215
# Name: aws, dtype: int64

# %%
#excel
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df.excel.value_counts()
# Out:
# 0    399
# 1    361
# Name: excel, dtype: int64

# %%
df.to_csv("Cleaned_dataset.csv",encoding="utf-8")

# %%
del df,min_hr,salary

# %%
#invoke garbage collector to free ram
import gc
gc.collect()
# Out:
# 76
